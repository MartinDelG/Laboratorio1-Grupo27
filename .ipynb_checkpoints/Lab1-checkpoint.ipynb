# %% [markdown]
# # Laboratorio 1: Grupo 27

# %% [markdown]
# Martín Del Gordo <br>
# Raul Insuasty <br>
# Nicolás Prada <br>

# %% [markdown]
# ## 1. Entendimiento de los datos

# %% [markdown]
# Vamos a empezar haciendo la importación de nuestras librerías.

# %%
import numpy as np
import pandas as pd

from joblib import dump, load

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import scipy.stats as stats

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 50)

# %%
db_location_train = './datos_entrenamiento_laboratorio1(train_data).csv'

# %%
jugadores_df = pd.read_csv(db_location_train, sep=';', encoding = "ISO-8859-1")

# %%
jugadores_df.shape
# Out:
# (57934, 50)

# %%
jugadores_df.columns
# Out:
# Index(['Jugador', 'Nacionalidad', 'Posicion', 'Edad', 'Dia_partido', 'Goles',
#        'Tiros Totales', 'xG', 'npxG', 'xAG', 'xAG.1',
#        'Acciones_que_crean_tiros', 'Pases_intentados', 'Pases_intentados.1',
#        'Pases_intentados.2', 'Pases_progresivos', 'Pases_progresivos.1',
#        'Regates_exitosos', 'Regates_exitosos.1', 'Pases_medios_completados',
#        'Pases_largos_completados', 'xAG.2', 'xAG.3', 'xA',
#        'Pases_en_ultimo_tercio', 'Pases_balon_vivo', 'Pases_balon_muerto',
#        'Pases_al_hueco', 'Pases_centros', 'Pases_completados',
#        'Pases_completados.1', 'Pases_completados.2', 'Pases_fuera_de_juego',
#        'Valla_no_vencida', 'Errores_defnsivos_ocasion_tiro',
#        'Toques_en_zona_ofensiva', 'Toques_en_area_rival',
#        '%_de_regates_exitosos', 'Veces_que_fue_barrido_regate',
#        'Acarreos_ultimo_tercio', 'Malos_controles', 'Perdida_balon',
#        'Pases_recibidos', 'Pases_progresivos_recibidos', 'Faltas_cometidas',
# ...

# %% [markdown]
# Primero filtramos las columnas duplicadas que arriba se mostraban con un numero al final de la columna.

# %%
#Se seleccionan las columnas unicas.
features = ['Jugador', 'Nacionalidad', 'Posicion', 'Edad', 'Dia_partido', 'Goles',
           'Tiros Totales', 'xG', 'npxG', 'xAG',
           'Acciones_que_crean_tiros', 'Pases_intentados', 'Pases_progresivos','Regates_exitosos', 
           'Pases_medios_completados',
           'Pases_largos_completados', 'xA',
           'Pases_en_ultimo_tercio', 'Pases_balon_vivo', 'Pases_balon_muerto',
           'Pases_al_hueco', 'Pases_centros', 'Pases_completados', 'Pases_fuera_de_juego',
           'Valla_no_vencida', 'Errores_defnsivos_ocasion_tiro',
           'Toques_en_zona_ofensiva', 'Toques_en_area_rival',
           '%_de_regates_exitosos', 'Veces_que_fue_barrido_regate',
           'Acarreos_ultimo_tercio', 'Malos_controles', 'Perdida_balon',
           'Pases_recibidos', 'Pases_progresivos_recibidos', 'Faltas_cometidas',
           'Centros', 'Duelos_aereos_ganados', '%_de_duelos_aereos_ganados',
           'market_value', 'contract_date']

# %% [markdown]
# Consideramos que la columna Dia_Partido no es importante para determinar el precio por lo que la descartaremos de nuestras columnas a estudiar

# %%
#Se quita la columna Dia_partido.
features = ['Jugador', 'Nacionalidad', 'Posicion', 'Edad', 'Goles',
           'Tiros Totales', 'xG', 'npxG', 'xAG',
           'Acciones_que_crean_tiros', 'Pases_intentados', 'Pases_progresivos','Regates_exitosos', 
           'Pases_medios_completados',
           'Pases_largos_completados', 'xA',
           'Pases_en_ultimo_tercio', 'Pases_balon_vivo', 'Pases_balon_muerto',
           'Pases_al_hueco', 'Pases_centros', 'Pases_completados', 'Pases_fuera_de_juego',
           'Valla_no_vencida', 'Errores_defnsivos_ocasion_tiro',
           'Toques_en_zona_ofensiva', 'Toques_en_area_rival',
           '%_de_regates_exitosos', 'Veces_que_fue_barrido_regate',
           'Acarreos_ultimo_tercio', 'Malos_controles', 'Perdida_balon',
           'Pases_recibidos', 'Pases_progresivos_recibidos', 'Faltas_cometidas',
           'Centros', 'Duelos_aereos_ganados', '%_de_duelos_aereos_ganados',
           'market_value', 'contract_date']

# %% [markdown]
# Por ultimo nos dimos cuenta que en el diccionario y en nuestros datos "Pases_centros" y "Centros" significaban lo mismo por lo que dejamos unicamente la columna Centros

# %%
#Se quita la columna Pases_Centros.
features = ['Jugador', 'Nacionalidad', 'Posicion', 'Edad', 'Goles',
           'Tiros Totales', 'xG', 'npxG', 'xAG',
           'Acciones_que_crean_tiros', 'Pases_intentados', 'Pases_progresivos','Regates_exitosos', 
           'Pases_medios_completados',
           'Pases_largos_completados', 'xA',
           'Pases_en_ultimo_tercio', 'Pases_balon_vivo', 'Pases_balon_muerto',
           'Pases_al_hueco', 'Pases_completados', 'Pases_fuera_de_juego',
           'Valla_no_vencida', 'Errores_defnsivos_ocasion_tiro',
           'Toques_en_zona_ofensiva', 'Toques_en_area_rival',
           '%_de_regates_exitosos', 'Veces_que_fue_barrido_regate',
           'Acarreos_ultimo_tercio', 'Malos_controles', 'Perdida_balon',
           'Pases_recibidos', 'Pases_progresivos_recibidos', 'Faltas_cometidas',
           'Centros', 'Duelos_aereos_ganados', '%_de_duelos_aereos_ganados',
           'market_value', 'contract_date']

# %% [markdown]
# ## 2. Perfilamiento y exploración de datos

# %%
jugadores_df = jugadores_df[features]

# %%
jugadores_df.shape
# Out:
# (57934, 39)

# %%
jugadores_df.head(5)
# Out:
#               Jugador Nacionalidad Posicion    Edad  Goles  Tiros Totales  \
# 0     Bruno Fernandes       pt POR    FW,AM  29-343      0              6
# 1     Marcus Rashford      eng ENG       LW  26-290      0              0
# 2         Amad Diallo       ci CIV       RW  22-036      0              0
# 3         Amad Diallo       ci CIV       RW  22-036     -5              0
# 4  Alejandro Garnacho       ar ARG       RW  20-046      0              2
#
#     xG  npxG  xAG  Acciones_que_crean_tiros  Pases_intentados  \
# 0  1.2   1.2  0.0                         2                60
# 1  0.0   0.0  0.7                         1                30
# 2  0.0   0.0  0.1                         1                33
# 3  0.0   0.0  0.1                         1                33
# 4  0.7   0.7  0.2                         3                11
#
#    Pases_progresivos  Regates_exitosos  Pases_medios_completados  \
# 0                  6                 1                        14
# ...

# %%
jugadores_df.dtypes
# Out:
# Jugador                            object
# Nacionalidad                       object
# Posicion                           object
# Edad                               object
# Goles                               int64
# Tiros Totales                       int64
# xG                                float64
# npxG                              float64
# xAG                               float64
# Acciones_que_crean_tiros            int64
# Pases_intentados                    int64
# Pases_progresivos                   int64
# Regates_exitosos                    int64
# Pases_medios_completados            int64
# Pases_largos_completados            int64
# xA                                float64
# Pases_en_ultimo_tercio              int64
# Pases_balon_vivo                    int64
# Pases_balon_muerto                  int64
# Pases_al_hueco                      int64
# Pases_completados                   int64
# Pases_fuera_de_juego                int64
# ...

# %% [markdown]
# Nos podemos dar cuenta que hay trabajo por hacer para las variables:
#  - Jugador (unificar los registros)
#  - Nacionalidad (Arreglar el formato, convertir a categórica)
#  - Posición (Convertir a categórica)
#  - Edad (dejar en años)
#  - Market Value (corregir el formato)
#  - Contract Date (dias para que venza el contrato)

# %%
pd.set_option("display.max_rows", None)  
jugadores_df.describe()
# Out:
#               Goles  Tiros Totales            xG          npxG           xAG  \
# count  57934.000000   57934.000000  57934.000000  57934.000000  57934.000000
# mean       0.513015       0.792402      0.088635      0.080473      0.062784
# std       16.440600       1.158538      0.209810      0.186549      0.152033
# min       -5.000000       0.000000      0.000000      0.000000      0.000000
# 25%        0.000000       0.000000      0.000000      0.000000      0.000000
# 50%        0.000000       0.000000      0.000000      0.000000      0.000000
# 75%        0.000000       1.000000      0.100000      0.100000      0.100000
# max      995.000000      12.000000      2.900000      2.900000      2.100000
#
#        Acciones_que_crean_tiros  Pases_intentados  Pases_progresivos  \
# count              57934.000000      57934.000000       57934.000000
# mean                   1.416750         31.659716           2.416232
# ...

# %%
pd.reset_option("display.max_rows")

# %%
pip install sweetviz
# Out:
# ...
#
# ...
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# ...
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/15.1 MB 9.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.9/15.1 MB 8.6 MB/s eta 0:00:02
#    ------------------ --------------------- 7.1/15.1 MB 11.0 MB/s eta 0:00:01
#    ------------------------- -------------- 9.7/15.1 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.1/15.1 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 15.1/15.1 MB 11.9 MB/s eta 0:00:00
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# ...
#
#    -------------------- ------------------- 1/2 [sweetviz]
#    ---------------------------------------- 2/2 [sweetviz]
#
# ...

# %%
# Selecciona solo las columnas numéricas
   #num_df = jugadores_df.select_dtypes(include=['int64', 'float64'])

# Calcula la matriz de correlación
    #corr = num_df.corr()

# Plot del heatmap
    #plt.figure(figsize=(12, 8))
    #sns.heatmap(corr, cmap="Blues", vmin=0, vmax=1, annot=False, fmt=".2f")
    #plt.title("Matriz de correlación entre variables numéricas")
    #plt.show()

# %%
#num_df.corr()
